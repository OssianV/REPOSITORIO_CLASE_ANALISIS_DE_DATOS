# %% [markdown]
# # Tests notebook

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("../INPUTS/tests.csv")

display(df.columns)
# Out:
# Index(['PRRIMERO', 'SEGUNDO', 'Unnamed: 2', 'CUARTO', 'Unnamed: 4', 'SEXTO',
#        'Unnamed: 6', 'Unnamed: 7', 'NOVENO'],
#       dtype='object')
